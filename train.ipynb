# %% [markdown]
# # `train.ipynb` - Model Training and Validation

# %%
import os
import time
from glob import glob
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
from data import DriveDataset
from model import build_unet
from loss import DiceBCELoss
from utils import seeding, create_dir, epoch_time
import gc

# %%
def load_data(path):
    """
    Loads paths for images and masks from the augmented dataset directory.
    """
    train_x = sorted(glob(os.path.join(path, "train", "image", "*")))
    train_y = sorted(glob(os.path.join(path, "train", "mask", "*")))
    
    test_x = sorted(glob(os.path.join(path, "test", "image", "*")))
    test_y = sorted(glob(os.path.join(path, "test", "mask", "*")))
    return (train_x, train_y), (test_x, test_y)

def train(model, loader, optimizer, loss_fn, device):
    """
    Handles the training phase for one epoch.
    """
    model.train()
    epoch_loss = 0.0

    for x, y in loader:
        x = x.to(device, dtype=torch.float32)
        y = y.to(device, dtype=torch.float32)

        optimizer.zero_grad()
        y_pred = model(x)
        loss = loss_fn(y_pred, y)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

    return epoch_loss / len(loader)

def evaluate(model, loader, loss_fn, device):
    """
    Handles the validation/evaluation phase.
    """
    model.eval()
    epoch_loss = 0.0

    with torch.no_grad():
        for x, y in loader:
            x = x.to(device, dtype=torch.float32)
            y = y.to(device, dtype=torch.float32)

            y_pred = model(x)
            loss = loss_fn(y_pred, y)
            epoch_loss += loss.item()

    return epoch_loss / len(loader)


if __name__ == "__main__":
    
    # Force clean GPU memory and garbage collector
    torch.cuda.empty_cache()
    gc.collect()
    
    
    seeding(42)
    # Create folder for saving model checkpoints
    create_dir("files")

    # Load Augmented Data Paths
    data_path = "D:/nada/______Projects/Retina-Blood-Vessel-Segmentation/new_data"
    (train_x, train_y), (valid_x, valid_y) = load_data(data_path)

    print(f"Dataset Size:\nTrain: {len(train_x)}\nValid: {len(valid_x)}")

    # Hyperparameters
    H = 512
    W = 512
    size = (H, W)
    batch_size = 1      # To prevent CUDA out of Memory
    num_epochs = 50     
    lr = 1e-4
    checkpoint_path = "files/checkpoint.pth"

    # Dataset & Loader Initialization
    train_dataset = DriveDataset(train_x, train_y)
    valid_dataset = DriveDataset(valid_x, valid_y)

    # num_workers=0 is required for stability on Windows with small GPU memory
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
    valid_loader = DataLoader(dataset=valid_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Training on: {device}")
    
    model = build_unet()
    model = model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5)
    loss_fn = DiceBCELoss()

    # Training Loop
    best_valid_loss = float("inf")
    
    print("Starting Training Loop...")

    for epoch in range(num_epochs):
        start_time = time.time()

        # Training 
        train_loss = train(model, train_loader, optimizer, loss_fn, device)
        
        # Validation 
        valid_loss = evaluate(model, valid_loader, loss_fn, device)

        # Save Checkpoint if validation loss improves
        if valid_loss < best_valid_loss:
            print(f"Valid loss improved from {best_valid_loss:2.4f} to {valid_loss:2.4f}. Saving Checkpoint...")
            best_valid_loss = valid_loss
            torch.save(model.state_dict(), checkpoint_path)

        # Calculate time taken for the epoch
        end_time = time.time()
        epoch_mins, epoch_secs = epoch_time(start_time, end_time)

        # Log epoch results
        print(f"Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s")
        print(f"Train Loss: {train_loss:.3f} | Valid Loss: {valid_loss:.3f}\n")
# Out:
# Dataset Size:
# Train: 80
# Valid: 20
# Training on: cuda
# Starting Training Loop...
# Valid loss improved from inf to 0.9976. Saving Checkpoint...
# Epoch: 01 | Time: 0m 26s
# Train Loss: 1.062 | Valid Loss: 0.998
#
# Valid loss improved from 0.9976 to 0.8784. Saving Checkpoint...
# Epoch: 02 | Time: 0m 26s
# Train Loss: 0.892 | Valid Loss: 0.878
#
# Valid loss improved from 0.8784 to 0.8100. Saving Checkpoint...
# Epoch: 03 | Time: 0m 26s
# Train Loss: 0.805 | Valid Loss: 0.810
#
# Valid loss improved from 0.8100 to 0.7429. Saving Checkpoint...
# Epoch: 04 | Time: 0m 26s
# Train Loss: 0.734 | Valid Loss: 0.743
#
# Valid loss improved from 0.7429 to 0.6836. Saving Checkpoint...
# Epoch: 05 | Time: 0m 26s
# Train Loss: 0.676 | Valid Loss: 0.684
#
# Valid loss improved from 0.6836 to 0.6306. Saving Checkpoint...
# Epoch: 06 | Time: 0m 26s
# Train Loss: 0.622 | Valid Loss: 0.631
#
# Valid loss improved from 0.6306 to 0.6043. Saving Checkpoint...
# Epoch: 07 | Time: 0m 27s
# Train Loss: 0.577 | Valid Loss: 0.604
#
# Valid loss improved from 0.6043 to 0.5585. Saving Checkpoint...
# Epoch: 08 | Time: 0m 26s
# Train Loss: 0.536 | Valid Loss: 0.559
#
# Valid loss improved from 0.5585 to 0.5307. Saving Checkpoint...
# Epoch: 09 | Time: 0m 27s
# Train Loss: 0.499 | Valid Loss: 0.531
#
# Valid loss improved from 0.5307 to 0.5247. Saving Checkpoint...
# Epoch: 10 | Time: 0m 26s
# Train Loss: 0.467 | Valid Loss: 0.525
#
# Valid loss improved from 0.5247 to 0.4786. Saving Checkpoint...
# Epoch: 11 | Time: 0m 26s
# Train Loss: 0.441 | Valid Loss: 0.479
#
# Valid loss improved from 0.4786 to 0.4692. Saving Checkpoint...
# Epoch: 12 | Time: 0m 26s
# Train Loss: 0.413 | Valid Loss: 0.469
#
# Epoch: 13 | Time: 0m 26s
# Train Loss: 0.393 | Valid Loss: 0.488
#
# Valid loss improved from 0.4692 to 0.4433. Saving Checkpoint...
# Epoch: 14 | Time: 0m 27s
# Train Loss: 0.377 | Valid Loss: 0.443
#
# Valid loss improved from 0.4433 to 0.4382. Saving Checkpoint...
# Epoch: 15 | Time: 0m 27s
# Train Loss: 0.353 | Valid Loss: 0.438
#
# Valid loss improved from 0.4382 to 0.4292. Saving Checkpoint...
# Epoch: 16 | Time: 0m 27s
# Train Loss: 0.337 | Valid Loss: 0.429
#
# Valid loss improved from 0.4292 to 0.4154. Saving Checkpoint...
# Epoch: 17 | Time: 0m 27s
# Train Loss: 0.320 | Valid Loss: 0.415
#
# Valid loss improved from 0.4154 to 0.4104. Saving Checkpoint...
# Epoch: 18 | Time: 0m 27s
# Train Loss: 0.306 | Valid Loss: 0.410
#
# Valid loss improved from 0.4104 to 0.4056. Saving Checkpoint...
# Epoch: 19 | Time: 0m 27s
# Train Loss: 0.290 | Valid Loss: 0.406
#
# Valid loss improved from 0.4056 to 0.4016. Saving Checkpoint...
# Epoch: 20 | Time: 0m 27s
# Train Loss: 0.273 | Valid Loss: 0.402
#
# Epoch: 21 | Time: 0m 27s
# Train Loss: 0.258 | Valid Loss: 0.407
#
# Epoch: 22 | Time: 0m 25s
# Train Loss: 0.245 | Valid Loss: 0.404
#
# Epoch: 23 | Time: 0m 26s
# Train Loss: 0.229 | Valid Loss: 0.413
#
# Epoch: 24 | Time: 0m 27s
# Train Loss: 0.221 | Valid Loss: 0.403
#
# Epoch: 25 | Time: 0m 27s
# Train Loss: 0.212 | Valid Loss: 0.419
#
# Epoch: 26 | Time: 0m 27s
# Train Loss: 0.201 | Valid Loss: 0.418
#
# Epoch: 27 | Time: 0m 27s
# Train Loss: 0.188 | Valid Loss: 0.415
#
# Epoch: 28 | Time: 0m 26s
# Train Loss: 0.176 | Valid Loss: 0.427
#
# Epoch: 29 | Time: 0m 26s
# Train Loss: 0.174 | Valid Loss: 0.424
#
# Epoch: 30 | Time: 0m 27s
# Train Loss: 0.165 | Valid Loss: 0.417
#
# Epoch: 31 | Time: 0m 26s
# Train Loss: 0.153 | Valid Loss: 0.439
#
# Epoch: 32 | Time: 0m 26s
# Train Loss: 0.147 | Valid Loss: 0.433
#
# Epoch: 33 | Time: 0m 26s
# Train Loss: 0.144 | Valid Loss: 0.436
#
# Epoch: 34 | Time: 0m 26s
# Train Loss: 0.140 | Valid Loss: 0.451
#
# Epoch: 35 | Time: 0m 26s
# Train Loss: 0.133 | Valid Loss: 0.433
#
# Epoch: 36 | Time: 0m 26s
# Train Loss: 0.124 | Valid Loss: 0.428
#
# Epoch: 37 | Time: 0m 25s
# Train Loss: 0.118 | Valid Loss: 0.436
#
# Epoch: 38 | Time: 0m 25s
# Train Loss: 0.116 | Valid Loss: 0.449
#
# Epoch: 39 | Time: 0m 25s
# Train Loss: 0.114 | Valid Loss: 0.448
#
# Epoch: 40 | Time: 0m 25s
# Train Loss: 0.108 | Valid Loss: 0.459
#
# Epoch: 41 | Time: 0m 25s
# Train Loss: 0.104 | Valid Loss: 0.451
#
# Epoch: 42 | Time: 0m 25s
# Train Loss: 0.107 | Valid Loss: 0.453
#
# Epoch: 43 | Time: 0m 26s
# Train Loss: 0.100 | Valid Loss: 0.452
#
# Epoch: 44 | Time: 0m 25s
# Train Loss: 0.093 | Valid Loss: 0.462
#
# Epoch: 45 | Time: 0m 26s
# Train Loss: 0.090 | Valid Loss: 0.458
#
# Epoch: 46 | Time: 0m 26s
# Train Loss: 0.090 | Valid Loss: 0.463
#
# Epoch: 47 | Time: 0m 26s
# Train Loss: 0.088 | Valid Loss: 0.468
#
# Epoch: 48 | Time: 0m 26s
# Train Loss: 0.083 | Valid Loss: 0.461
#
# Epoch: 49 | Time: 0m 25s
# Train Loss: 0.079 | Valid Loss: 0.468
#
# Epoch: 50 | Time: 0m 26s
# Train Loss: 0.076 | Valid Loss: 0.471
